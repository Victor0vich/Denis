# %% [markdown]
# # Введение в обработку табличных данных и в библиотеку Pandas

# %% [markdown]
# Библиотеки в Python представляют собой наборы связанных модулей, объединенных для решения определенных задач или предоставления специфического функционала. Они расширяют базовый функционал Python, позволяя разработчикам использовать готовые решения для различных целей, вместо того чтобы писать все с нуля. Библиотеки могут быть как встроенными в Python, например, os, sys или math, так и сторонними, которые необходимо устанавливать отдельно.

# %% [markdown]
# Модули в Python - это файлы с расширением .py, содержащие код на языке Python. Они служат для хранения функций, классов, переменных и других элементов, которые могут быть использованы в других программах. Модули позволяют организовать код, сделать его более читаемым и повторно используемым. Для импорта модуля используется инструкция import, которая позволяет получить доступ к его содержимому в текущей программе.

# %%
import pandas as pd # загружаем необходимую библиотеку

# %% [markdown]
# Модуль pandas языка Python поддерживает работу с широким спектром форматов файлов, включая:
# * Comma-separated values (CSV) - стандартный формат для обмена данными между различными программами.
# * XLSX - формат электронных таблиц Microsoft Excel.
# * Plain Text (txt) - простой текстовый формат, который может использоваться для хранения небольших объемов данных.
# * JSON - формат обмена данными, основанный на JavaScript Object Notation.
# * и многие другие....

# %% [markdown]
# Для начала давайте откроем наш файл:

# %%
df = pd.read_csv('customer_shopping_data.csv') # открываем нужный файл и записываем его в переменную df
df.head() # выводим первые пять строк
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card     5/8/2022          Kanyon
# 1     Debit Card   12/12/2021  Forum Istanbul
# 2           Cash    9/11/2021       Metrocity
# 3    Credit Card   16/05/2021    Metropol AVM
# 4           Cash   24/10/2021          Kanyon

# %% [markdown]
# Описание колонок:
#
# * invoice_no - номер счёта-фактуры
# * customer_id - id клиента
# * gender - пол
# * age - возраст
# * category - категория покупок
# * quantity - количество
# * price - цена
# * payment_method - способ оплаты
# * invoice_date - дата
# * shopping_mall - название ТРЦ

# %% [markdown]
# Можно узнать, сколько всего строк и столбцов в нашей таблице:

# %%
df.shape # размерность таблички
# Out:
# (99457, 10)

# %% [markdown]
# Получается, что всего 99457 строк и 10 столбцов.

# %% [markdown]
# Также можно достать более развернутую информацию про наши данные:

# %%
df.info() # метод info() возвращает информацию о таблице
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      99457 non-null  object
#  1   customer_id     99457 non-null  object
#  2   gender          99457 non-null  object
#  3   age             99457 non-null  int64
#  4   category        99457 non-null  object
#  5   quantity        99457 non-null  int64
#  6   price           99457 non-null  float64
#  7   payment_method  99457 non-null  object
#  8   invoice_date    99457 non-null  object
#  9   shopping_mall   99457 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 7.6+ MB

# %% [markdown]
# Как прочитать таблицу выше?
# 1. `<class 'pandas.core.frame.DataFrame'>` – Python видит нашу таблицу как объект DataFrame.
# 2. `RangeIndex: 99457 entries, 0 to 99456` – в таблице 99457 строк с индексами от 0 до 99456. В Python все считается с 0, а не 1, как мы привыкли.
# 3. `Data columns (total 10 columns):` – в таблице 10 колонок.
# 4. После выводится небольшая таблица с информацией о названии колонки (`Column`), количестве непустых ячеек в колонке (`Non-Null Count`), а также тип данных (`Dtype`).
# 5. `dtypes: float64(1), int64(2), object(7)` – сводка по количеству столбцов с разными типами данных.
# 6. `memory usage: 7.6+ MB` – сколько памяти занимает таблица.

# %% [markdown]
# ## Обращение к данным в таблице

# %% [markdown]
# ### Обращение к столбцам
#
# `датафрейм['столбец']` или `датафрейм.столбец` – обращение к одному столбцу
#
# `датафрейм[['столбец 1', 'столбец 2', ...]]` – обращение к нескольким столбцам

# %%
df['price'] # данные столбца с ценами
# Out:
# 0        1500.40
# 1        1800.51
# 2         300.08
# 3        3000.85
# 4          60.60
#           ...
# 99452      58.65
# 99453      10.46
# 99454      10.46
# 99455    4200.00
# 99456      35.19
# Name: price, Length: 99457, dtype: float64

# %%
['category', 'price']

# %%
df[['category', 'price']] # мини-таблица с категориями товаров и ценами
# Out:
#               category    price
# 0             Clothing  1500.40
# 1                Shoes  1800.51
# 2             Clothing   300.08
# 3                Shoes  3000.85
# 4                Books    60.60
# ...                ...      ...
# 99452         Souvenir    58.65
# 99453  Food & Beverage    10.46
# 99454  Food & Beverage    10.46
# 99455       Technology  4200.00
# 99456         Souvenir    35.19
#
# [99457 rows x 2 columns]

# %% [markdown]
# ## Фильтрация данных

# %% [markdown]
# ### Фильтрация по столбцу
#
# `датафрейм[датафрейм['столбец'] <оператор сравнения> условие]`
#
# |Оператор|Значение|
# |:---:|:---:|
# |==|равно|
# |!=|не равно|
# |>|больше чем|
# |<|меньше чем|
# |>=|больше или равно чем|
# |<=|меньше или равно чем|

# %%
5 == 5
# Out:
# True

# %% [markdown]
# Найдем покупки, где цена более 3000:

# %%
df[df['price'] < 100]
# Out:
#       invoice_no customer_id  gender  age         category  quantity  price  \
# 4        I337046     C189076  Female   53            Books         4  60.60
# 6        I121056     C151197  Female   49        Cosmetics         1  40.66
# 10       I306368     C240286  Female   36  Food & Beverage         2  10.46
# 11       I139207     C191708  Female   29            Books         1  15.15
# 16       I294687     C300786    Male   65            Books         2  30.30
# ...          ...         ...     ...  ...              ...       ...    ...
# 99450    I170504     C226974  Female   28            Books         1  15.15
# 99452    I219422     C441542  Female   45         Souvenir         5  58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2  10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2  10.46
# 99456    I232867     C273973  Female   36         Souvenir         3  35.19
#
#       payment_method invoice_date      shopping_mall
# 4               Cash   24/10/2021             Kanyon
# 6               Cash   13/03/2022       Istinye Park
# 10              Cash   25/12/2022          Metrocity
# 11       Credit Card   28/10/2022  Emaar Square Mall
# 16        Debit Card   16/01/2021          Metrocity
# ...              ...          ...                ...
# 99450           Cash   28/02/2023       Zorlu Center
# 99452    Credit Card   21/09/2022             Kanyon
# 99453           Cash   22/09/2021     Forum Istanbul
# 99454     Debit Card   28/03/2021          Metrocity
# 99456    Credit Card   15/10/2022   Mall of Istanbul
#
# [34674 rows x 10 columns]

# %% [markdown]
# Найдем покупки, совершенные женщинами:

# %%
df[df['gender'] == 'Female']
# Out:
#       invoice_no customer_id  gender  age   category  quantity    price  \
# 0        I138884     C241288  Female   28   Clothing         5  1500.40
# 3        I173702     C988172  Female   66      Shoes         5  3000.85
# 4        I337046     C189076  Female   53      Books         4    60.60
# 5        I227836     C657758  Female   28   Clothing         5  1500.40
# 6        I121056     C151197  Female   49  Cosmetics         1    40.66
# ...          ...         ...     ...  ...        ...       ...      ...
# 99447    I281214     C288090  Female   37       Toys         3   107.52
# 99448    I332105     C231387  Female   65      Shoes         4  2400.68
# 99450    I170504     C226974  Female   28      Books         1    15.15
# 99452    I219422     C441542  Female   45   Souvenir         5    58.65
# 99456    I232867     C273973  Female   36   Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 0        Credit Card     5/8/2022            Kanyon
# 3        Credit Card   16/05/2021      Metropol AVM
# 4               Cash   24/10/2021            Kanyon
# 5        Credit Card   24/05/2022    Forum Istanbul
# 6               Cash   13/03/2022      Istinye Park
# ...              ...          ...               ...
# 99447           Cash   21/02/2021      Metropol AVM
# 99448    Credit Card   29/08/2021      Metropol AVM
# 99450           Cash   28/02/2023      Zorlu Center
# 99452    Credit Card   21/09/2022            Kanyon
# 99456    Credit Card   15/10/2022  Mall of Istanbul
#
# [59482 rows x 10 columns]

# %% [markdown]
# ### Фильтрация по нескольким условиям
#
# `&` - и \
# `|` - или
#
# Все условия должны быть в скобках!

# %% [markdown]
# Найдем покупки, совершенные женщинами старше 40 из категории одежды:

# %%
df[(df['gender'] == 'Female')|(df['age'] > 40)]
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# 5        I227836     C657758  Female   28         Clothing         5  1500.40
# 6        I121056     C151197  Female   49        Cosmetics         1    40.66
# ...          ...         ...     ...  ...              ...       ...      ...
# 99451    I675411     C513603    Male   50             Toys         5   179.20
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 0        Credit Card     5/8/2022            Kanyon
# 3        Credit Card   16/05/2021      Metropol AVM
# 4               Cash   24/10/2021            Kanyon
# 5        Credit Card   24/05/2022    Forum Istanbul
# 6               Cash   13/03/2022      Istinye Park
# ...              ...          ...               ...
# 99451           Cash    9/10/2021      Metropol AVM
# 99452    Credit Card   21/09/2022            Kanyon
# 99454     Debit Card   28/03/2021         Metrocity
# 99455           Cash   16/03/2021      Istinye Park
# 99456    Credit Card   15/10/2022  Mall of Istanbul
#
# [81640 rows x 10 columns]

# %%
df[(df['gender'] == 'Female')&(df['age'] > 40)&(df['category'] == 'Clothing')]
# Out:
#       invoice_no customer_id  gender  age  category  quantity    price  \
# 9        I326945     C283361  Female   60  Clothing         2   600.16
# 14       I336189     C555402  Female   67  Clothing         2   600.16
# 18       I993048     C218149  Female   46  Clothing         2   600.16
# 37       I187519     C450287  Female   59  Clothing         2   600.16
# 47       I205366     C241642  Female   43  Clothing         4  1200.32
# ...          ...         ...     ...  ...       ...       ...      ...
# 99408    I949512     C217355  Female   47  Clothing         2   600.16
# 99435    I141871     C298790  Female   62  Clothing         3   900.24
# 99436    I579905     C265057  Female   57  Clothing         5  1500.40
# 99440    I887161     C137631  Female   58  Clothing         1   300.08
# 99442    I105959     C131810  Female   45  Clothing         4  1200.32
#
#       payment_method invoice_date      shopping_mall
# 9        Credit Card   22/08/2021             Kanyon
# 14       Credit Card     3/6/2022             Kanyon
# 18              Cash   26/07/2021       Metropol AVM
# 37       Credit Card     8/7/2022          Metrocity
# 47        Debit Card    7/11/2022       Zorlu Center
# ...              ...          ...                ...
# 99408    Credit Card   21/02/2021          Metrocity
# 99435           Cash     2/2/2022  Emaar Square Mall
# 99436           Cash   27/03/2022        Cevahir AVM
# 99440           Cash   22/06/2021             Kanyon
# 99442     Debit Card     1/2/2021       Istinye Park
#
# [11404 rows x 10 columns]

# %%
df[df['shopping_mall'].str.contains('P')]
# Out:
#       invoice_no customer_id  gender  age    category  quantity    price  \
# 6        I121056     C151197  Female   49   Cosmetics         1    40.66
# 25       I195396     C285161    Male   51        Toys         2    71.68
# 29       I209744     C251229    Male   29   Cosmetics         3   121.98
# 51       I202367     C317478  Female   41       Books         3    45.45
# 52       I664787     C237330  Female   53   Cosmetics         2    81.32
# ...          ...         ...     ...  ...         ...       ...      ...
# 99425    I584546     C764488  Female   39        Toys         2    71.68
# 99426    I126160     C145665  Female   19       Shoes         1   600.17
# 99429    I208840     C219131  Female   58        Toys         1    35.84
# 99442    I105959     C131810  Female   45    Clothing         4  1200.32
# 99455    I702964     C800631    Male   56  Technology         4  4200.00
#
#       payment_method invoice_date shopping_mall
# 6               Cash   13/03/2022  Istinye Park
# 25        Debit Card   16/05/2021  Istinye Park
# 29       Credit Card   29/04/2021  Istinye Park
# 51              Cash   24/02/2023  Istinye Park
# 52       Credit Card    12/1/2023  Istinye Park
# ...              ...          ...           ...
# 99425     Debit Card   26/09/2022  Istinye Park
# 99426     Debit Card     8/1/2022  Istinye Park
# 99429    Credit Card   18/02/2023  Istinye Park
# 99442     Debit Card     1/2/2021  Istinye Park
# 99455           Cash   16/03/2021  Istinye Park
#
# [9781 rows x 10 columns]

# %% [markdown]
# Если хочется, то можно дальше использовать именно отфильтрованные данные:

# %%
df2 = df[(df['gender'] == 'Female')&(df['age'] > 40)&(df['category'] == 'Clothing')]

# %% [markdown]
# ## Сортировка данных
#
# ### По одному условию
#
# `датафрейм.sort_values('столбец')` – сортировка по одному столбцу (от наименьшего к наибольшему)
# `датафрейм.sort_values('столбец', ascending=False)` – сортировка по одному столбцу (от наибольшего к наименьшему)

# %%
df.sort_values('price')
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 69828    I296894     C778937  Female   24  Food & Beverage         1     5.23
# 76187    I276335     C281076  Female   52  Food & Beverage         1     5.23
# 90918    I102783     C816576  Female   56  Food & Beverage         1     5.23
# 41259    I201878     C310192    Male   57  Food & Beverage         1     5.23
# 28956    I243737     C118327    Male   54  Food & Beverage         1     5.23
# ...          ...         ...     ...  ...              ...       ...      ...
# 57523    I321312     C286227    Male   21       Technology         5  5250.00
# 41985    I117110     C157996  Female   67       Technology         5  5250.00
# 96366    I216069     C491682    Male   69       Technology         5  5250.00
# 85440    I573681     C772125  Female   47       Technology         5  5250.00
# 56167    I258716     C927194  Female   38       Technology         5  5250.00
#
#       payment_method invoice_date      shopping_mall
# 69828     Debit Card     5/6/2022   Mall of Istanbul
# 76187     Debit Card     8/3/2022          Metrocity
# 90918           Cash     5/2/2023       Istinye Park
# 41259     Debit Card    12/6/2021  Emaar Square Mall
# 28956           Cash   11/11/2022       Metropol AVM
# ...              ...          ...                ...
# 57523    Credit Card   31/12/2022     Forum Istanbul
# 41985    Credit Card   14/01/2023       Metropol AVM
# 96366           Cash    3/10/2021             Kanyon
# 85440           Cash   30/07/2022     Viaport Outlet
# 56167    Credit Card   31/01/2021  Emaar Square Mall
#
# [99457 rows x 10 columns]

# %%
df.sort_values(['age', 'price'], ascending = [True, False])
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 1469     I857861     C272918    Male   18       Technology         5  5250.00
# 11507    I161897     C131511  Female   18       Technology         5  5250.00
# 20396    I268105     C312131    Male   18       Technology         5  5250.00
# 26836    I246625     C311215    Male   18       Technology         5  5250.00
# 28087    I129827     C599136  Female   18       Technology         5  5250.00
# ...          ...         ...     ...  ...              ...       ...      ...
# 97251    I119564     C218137  Female   69  Food & Beverage         1     5.23
# 98206    I147947     C201510  Female   69  Food & Beverage         1     5.23
# 98373    I148114     C277250    Male   69  Food & Beverage         1     5.23
# 98464    I245951     C418711  Female   69  Food & Beverage         1     5.23
# 99321    I234667     C321665    Male   69  Food & Beverage         1     5.23
#
#       payment_method invoice_date     shopping_mall
# 1469            Cash   30/04/2022  Mall of Istanbul
# 11507           Cash   27/12/2021    Viaport Outlet
# 20396    Credit Card   29/04/2021  Mall of Istanbul
# 26836           Cash   29/11/2022       Cevahir AVM
# 28087           Cash   28/12/2021  Mall of Istanbul
# ...              ...          ...               ...
# 97251     Debit Card   19/07/2021         Metrocity
# 98206    Credit Card   15/08/2022  Mall of Istanbul
# 98373           Cash     9/5/2022  Mall of Istanbul
# 98464           Cash   20/11/2022  Mall of Istanbul
# 99321     Debit Card   11/10/2021      Metropol AVM
#
# [99457 rows x 10 columns]

# %% [markdown]
# ## Простейшая аналитика

# %% [markdown]
# ### Немного про категориальные переменные:

# %% [markdown]
# Узнаем, какие есть уникальные категории покупок:

# %%
df['category'].unique()
# Out:
# array(['Clothing', 'Shoes', 'Books', 'Cosmetics', 'Food & Beverage',
#        'Toys', 'Technology', 'Souvenir'], dtype=object)

# %% [markdown]
# Теперь узнаем, какие из них встречаются чаще, а какие реже:

# %%
df['category'].value_counts()
# Out:
# category
# Clothing           34487
# Cosmetics          15097
# Food & Beverage    14776
# Toys               10087
# Shoes              10034
# Souvenir            4999
# Technology          4996
# Books               4981
# Name: count, dtype: int64

# %% [markdown]
# ### И про числовые:

# %% [markdown]
# Минимальная цена:

# %%
df['price'].min()
# Out:
# 5.23

# %% [markdown]
# Средняя цена:

# %%
df['price'].mean()
# Out:
# 689.2563209226097

# %% [markdown]
# Давайте посмотрим на описательные статистики с помощью метода `.describe()`.
#
# * **count** – число непустых (заполненных) значений
# * **mean** – среднее арифметическое
# * **std** – стандартное отклонение (показатель разброса данных относительно среднего значения)
# * **min** – минимальное значение
# * **max** – максимальное значение
# * **25%** – нижний квартиль (значение, которое 25% значений не превышают)
# * **50%** – медиана (значение, которое 50% значений не превышают)
# * **75%** – верхний квартиль (значение, которое 75% значений не превышают)

# %%
df['price'].describe()
# Out:
# count    99457.000000
# mean       689.256321
# std        941.184567
# min          5.230000
# 25%         45.450000
# 50%        203.300000
# 75%       1200.320000
# max       5250.000000
# Name: price, dtype: float64

# %% [markdown]
# А если по отдельным категориям?

# %%
df.groupby('category')['price'].mean()
# Out:
# category
# Books                45.568621
# Clothing            901.084021
# Cosmetics           122.448626
# Food & Beverage      15.671948
# Shoes              1807.388568
# Souvenir             34.894345
# Technology         3156.935548
# Toys                107.733185
# Name: price, dtype: float64
